# %%
import numpy as np
import pandas as pd

# %%
train = r"D:\LULC\raw_data\0_groundtruth\SACLAJ_2014_2016_catclearned.csv"
train = r"D:\LULC\raw_data\0_groundtruth\SACLAJ-master.csv"
df_train = pd.read_csv(train)
df_train
# Out:
# C:\Users\GE\Anaconda3\envs\LULC\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           id           photo_date                            file_name  \
# 0          1  2014:04:14 15:06:48  2014_0414_1506_N35E139_cimg3174.jpg
# 1          2  2013:12:02 15:11:33             20131202miyakojima_2.JPG
# 2          3  2013:10:17 12:47:35                20131017watari_13.JPG
# 3          4  2013:10:17 13:13:10                20131017watari_11.JPG
# 4          5  2013:10:17 13:23:22                20131017watari_12.JPG
# ...      ...                  ...                                  ...
# 62254  62348  2080:01:09 01:53:20                         CIMG9611.JPG
# 62255  62349  2080:01:09 01:53:13                         CIMG9610.JPG
# 62256  62350  2080:01:09 01:53:08                         CIMG9609.JPG
# 62257  62351  2080:01:05 23:59:46                         CIMG9608.JPG
# 62258  62352  2080:01:05 23:59:57                         CIMG9999.JPG
#
#       category_master    category category_details  diameter  target_lat  \
# 0           JAXA_LULC         dbf              NaN       100   35.560440
# 1           JAXA_LULC  other crop              NaN        30   24.824808
# 2           JAXA_LULC        rice       rice paddy        80   38.062115
# 3           JAXA_LULC        rice       rice paddy        40   38.062504
# 4           JAXA_LULC  other crop          soybean        30   38.062672
# ...               ...         ...              ...       ...         ...
# 62254       JAXA_LULC  grasslands              NaN        30   47.778181
# 62255       JAXA_LULC  grasslands              NaN        30   47.778165
# 62256       JAXA_LULC  grasslands              NaN        30   47.778277
# 62257       JAXA_LULC  grasslands              NaN        30   47.778133
# 62258       JAXA_LULC  grasslands              NaN        30   45.854127
#
#        target_lon  photographer_lat  photographer_lon  sgli_lat  sgli_lon  \
# 0      139.212692         35.563698        139.205652       NaN       NaN
# 1      125.318985         24.824607        125.318993       NaN       NaN
# 2      140.890457         38.062573        140.889882       NaN       NaN
# 3      140.881317         38.061897        140.881142       NaN       NaN
# 4      140.882278         38.062672        140.882068       NaN       NaN
# ...           ...               ...               ...       ...       ...
# 62254  106.743815         47.777925        106.742672       NaN       NaN
# 62255  106.743982         47.777925        106.742672       NaN       NaN
# 62256  106.744125         47.777925        106.742672       NaN       NaN
# 62257  106.744244         47.777925        106.742672       NaN       NaN
# 62258  106.334897         45.854032        106.334585       NaN       NaN
#
#       note     created_at      updated_at        nickname Unnamed: 17
# 0      NaN  2014/8/8 2:26  2016/12/8 6:37  Kenlo Nasahara         NaN
# 1      NaN  2014/8/8 2:26  2016/12/8 6:36     anonymous53         NaN
# 2      NaN  2014/8/8 2:27  2016/12/8 6:36     anonymous53         NaN
# 3      NaN  2014/8/8 2:27  2016/12/8 6:36     anonymous53         NaN
# 4      NaN  2014/8/8 2:27  2016/7/21 6:09     anonymous53         NaN
# ...    ...            ...             ...             ...         ...
# 62254  NaN        25:25.7         25:25.7         undrakh         NaN
# 62255  NaN        25:32.5         25:32.5         undrakh         NaN
# 62256  NaN        25:38.4         25:38.4         undrakh         NaN
# 62257  NaN        25:44.1         25:44.1         undrakh         NaN
# 62258  NaN        20:18.3         20:18.3         undrakh         NaN
#
# [62259 rows x 18 columns]

# %%
unique = np.unique(df_train["category"])
unique
# Out:
# array(['aquaculture', 'bamboo', 'barren', 'broadleaf forests',
#        'closed shrublands', 'croplands', 'dbf', 'dbf/plantation',
#        'deciduous forests', 'dnf', 'ebf', 'ebf/plantation', 'enf',
#        'evergreen forests', 'forest', 'grasslands', 'herbs', 'lands',
#        'mixed forests', 'needleleaf forests', 'non-vegetation',
#        'open shrublands', 'orchard', 'other crop', 'pasture', 'rice',
#        'savannas', 'shrublands', 'snow and ice', 'urban and built-up',
#        'vegetation', 'water area', 'wetlands', 'wood lands'], dtype=object)

# %%
len(unique)
# Out:
# 34

# %%
hand_unique = ['Water', 'Urban and built-up', 'Rice paddy', 'Crops', 'Grassland', 'DBF', 'DNF', 'EBF', 'ENF', 'Bare land']
for i in hand_unique:
    num = sum(df_train["category"]==i)
    print(f"{i} = {num}個")
# Out:
# Water = 1714個
# Urban and built-up = 3500個
# Rice paddy = 8775個
# Crops = 6313個
# Grassland = 3807個
# DBF = 3246個
# DNF = 438個
# EBF = 1242個
# ENF = 4176個
# Bare land = 877個

# %%
df_train["category"].describe()
# Out:
# count          34088
# unique            10
# top       Rice paddy
# freq            8775
# Name: category, dtype: object
